# %%
# silencing warnings
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

sns.set_theme(palette="Set2")

# %% [markdown]
# # White noise, red noise and random walk

# %%
def random_walk(obs=100, d=1):
    """
    :param: obs: number of observations
    :param: d: number of dimensions
    """
    return np.cumsum(np.random.normal(0, 0.5, (obs, d)))

def white_noise(obs=100, d=1):
    return np.random.normal(0, 0.5, (obs, d)).flatten()

def red_noise(obs=100, d=1, corr=0.8):
    white = white_noise(obs, d)
    red = np.zeros_like(white)
    for i in range(1, len(white)):
        red[i] = corr * red[i-1] + white[i]
    return red

# %%
def build_graph(nobs=500):
    dts = pd.date_range(start="2020-01-01", periods=nobs)
    rw = pd.Series(random_walk(nobs), index=dts)
    wn = pd.Series(white_noise(nobs), index=dts)
    rn = pd.Series(red_noise(nobs, corr=0.7), index=dts)
    df = pd.concat([rw, wn, rn], axis=1)
    df.columns = ["random walk", "white noise", "red noise"]
    df.plot(figsize=(12, 3), use_index=True)

build_graph()

# %%
def two_rws(nobs=200):
    dts = pd.date_range(start="2000-01-01", periods=nobs)
    rw1 = pd.Series(random_walk(nobs), index=dts)
    rw2 = pd.Series(random_walk(nobs), index=dts)
    df = pd.concat([rw1, rw2], axis=1)
    df.columns = ["random walk 1", "random walk 2"]
    df.plot(figsize=(12, 7), use_index=True)

two_rws()

# %% [markdown]
# # Stationarity tests
#
# Augmented Dickey-Fuller test, [documentation](https://www.statsmodels.org/stable/generated/statsmodels.tsa.stattools.adfuller.html).

# %%
from statsmodels.tsa.stattools import adfuller

rw = random_walk(200)
wn = white_noise(200)
rn = red_noise(200, corr=0.7)

# use regression="nc" for statsmodels <=0.12.2 else regression="n"

# random walk
adf_stat, pval, lags, obs, crit_vals, icbest = adfuller(rw, regression="n")
print(f"ADF statistic: {adf_stat}")
print(f"p-value: {pval}")
print(f"Critical values: {crit_vals}")
# Out:
# ADF statistic: -1.3884934110042257
# p-value: 0.1534785823816146
# Critical values: {'1%': np.float64(-2.5774831803385414), '5%': np.float64(-1.9424858284561723), '10%': np.float64(-1.6155067050736038)}

# %%
# white noise
adf_stat, pval, lags, obs, crit_vals, icbest = adfuller(wn, regression="n")
print(f"ADF statistic: {adf_stat}")
print(f"p-value: {pval}")
print(f"Critical values: {crit_vals}")
# Out:
# ADF statistic: -13.373710684710197
# p-value: 2.559453736023125e-24
# Critical values: {'1%': np.float64(-2.5770667644756444), '5%': np.float64(-1.942430759336949), '10%': np.float64(-1.615550641718986)}

# %%
# red noise
adf_stat, pval, lags, obs, crit_vals, icbest = adfuller(rn, regression="n")
print(f"ADF statistic: {adf_stat}")
print(f"p-value: {pval}")
print(f"Critical values: {crit_vals}")
# Out:
# ADF statistic: -6.5119329438211455
# p-value: 7.329612374026887e-10
# Critical values: {'1%': np.float64(-2.577124435261708), '5%': np.float64(-1.9424383763922255), '10%': np.float64(-1.6155445459389322)}

# %% [markdown]
# # Log transformation

# %%
nobs = 200
dts = pd.date_range(start="2000-01-01", periods=nobs)
rw1 = pd.Series(abs(random_walk(nobs)), index=dts)
rw2 = pd.Series(np.log(rw1 + 1), index=dts)
df = pd.concat([rw1, rw2], axis=1)
df.columns = ["random walk 1", "log-transformed random walk 1"]
df.plot(figsize=(10, 7), use_index=True)
# Out:
# <Axes: >

# %% [markdown]
# # Differencing

# %%
rw2 = pd.Series(rw1.diff().dropna(), index=dts)
df = pd.concat([rw1, rw2], axis=1)
df.columns = ["random walk 1", "differenced random walk 1"]
df.plot(figsize=(10, 7), use_index=True)
# Out:
# <Axes: >

# %% [markdown]
# # Seasonal differencing
#
# Because in the CO2 variable there appears to be seasonality, whose cycle equals one year, and there are monthly observations, we will subtract from each value the value located at 12 lags from it.
#
# The first 12 values will be NaN, so we delete them.

# %%
df_co2 = pd.read_excel("https://github.com/PacktPublishing/Practical-Time-Series-Analysis/raw/master/Data%20Files/Monthly_CO2_Concentrations.xlsx",
                      ).dropna()
df_co2.head()
# Out:
#       CO2    Year  Month
# 0  333.13  1974.0    5.0
# 1  332.09  1974.0    6.0
# 2  331.10  1974.0    7.0
# 3  329.14  1974.0    8.0
# 4  327.36  1974.0    9.0

# %%
# create a datetime index from the year and month columns
df_co2["date"] = pd.to_datetime(df_co2[["Year", "Month"]].assign(day=1))
df_co2.set_index("date", inplace=True)
df_co2 = df_co2[["CO2"]].interpolate()

# %%
df_co2.plot()
# Out:
# <Axes: xlabel='date'>

# %%
from sklearn.linear_model import LinearRegression

trend_model = LinearRegression(fit_intercept=True)

X = np.arange(len(df_co2)).reshape((-1,1))
y = df_co2['CO2']
trend_model.fit(X, y)
intercept = trend_model.intercept_
coef = trend_model.coef_[0]
print(f'Trend model intercept={intercept} coefficient={coef}')
# Out:
# Trend model intercept=329.45310559006214 coefficient=0.12099301242236019

# %%
df_co2['trendline'] = trend_model.predict(X)

# %%
detrended = df_co2['CO2'] - df_co2['trendline']

# %%
shifted = detrended.shift(12)[12:]

# %% [markdown]
# Similarly, delete the first 12 values from the original series.

# %%
shortened = detrended[12:]

# %%
season_differenced = shortened - shifted

df = pd.concat([detrended, season_differenced], axis=1)
df.columns = ["Original", "Season-differenced"]
df.plot(figsize=(10, 7), use_index=True)
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# # Citing this notebook
#
# If you use this notebook in your work, please cite it as follows:
#
# Pekar, V. (2026). Machine Learning for Business Analytics. Lecture examples and exercises. (Version 1.0.0). URL: https://github.com/vpekar/bd4dm
