# %% [markdown]
# Make sure imblearn is installed:

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\pekarv\anaconda3\envs\.env\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\pekarv\anaconda3\envs\.env\lib\site-packages (from imblearn) (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\pekarv\anaconda3\envs\.env\lib\site-packages (from imbalanced-learn->imblearn) (1.26.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\pekarv\anaconda3\envs\.env\lib\site-packages (from imbalanced-learn->imblearn) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\pekarv\anaconda3\envs\.env\lib\site-packages (from imbalanced-learn->imblearn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\pekarv\anaconda3\envs\.env\lib\site-packages (from imbalanced-learn->imblearn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\pekarv\anaconda3\envs\.env\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)

# %% [markdown]
# Note: if you are using sklearn=1.3, it needs to be downgraded for the code below to work:
#
# !pip uninstall scikit-learn --yes
#
# !pip uninstall imblearn --yes
#
# !pip install scikit-learn==1.2.2
#
# !pip install imblearn

# %%
import pandas as pd
import numpy as np
import seaborn as sns

from sklearn.model_selection import train_test_split

sns.set_theme(palette="Set2")

# execution time
from timeit import default_timer as timer
from datetime import timedelta

# increase column width
pd.set_option('display.max_colwidth', 250)

# silence warnings
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# # Load the data

# %%
import os
import tarfile
import urllib


# the file is archived with tar and gunzip
URL = "https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz"

def get_dataframe():
    global URL
    
    # if the "datasets" folder does not exist, create it
    if not os.path.exists("datasets"):
        os.makedirs("datasets")
    
    # if the archived file does not exist, download it
    if not os.path.exists("datasets/housing.tgz"):
        urllib.request.urlretrieve(URL, "datasets/housing.tgz")
    
    # if the unpacked file does not exist, unpack it
    if not os.path.exists("datasets/housing.csv"):
        infile = tarfile.open("datasets/housing.tgz")
        infile.extractall(path="datasets")
        infile.close()
    
    # load the dataframe
    return pd.read_csv("datasets/housing.csv")

df = get_dataframe()

# %% [markdown]
# # Train-test split

# %%
df["income_cat"] = pd.cut(df["median_income"], bins=[0., 1.5, 3.0, 4.5, 6., np.inf],
                          labels=[1, 2, 3, 4, 5])
trainset, testset = train_test_split(df, test_size=0.2, random_state=7,
                                     stratify=df["income_cat"])
del trainset["income_cat"]
del testset["income_cat"]

# %% [markdown]
# # Repeat initial preprocessing steps

# %% [markdown]
# ## Feature engineering

# %%
# create two new features
trainset["rooms_per_household"] = trainset["total_rooms"]/trainset["households"]
trainset["population_per_household"] = trainset["population"]/trainset["households"]
testset["rooms_per_household"] = testset["total_rooms"]/testset["households"]
testset["population_per_household"] = testset["population"]/testset["households"]

# rename "ISLAND" to "NEAR OCEAN"
trainset["ocean_proximity"] = trainset["ocean_proximity"].replace("ISLAND", "NEAR OCEAN")
testset["ocean_proximity"] = testset["ocean_proximity"].replace("ISLAND", "NEAR OCEAN")
trainset["ocean_proximity"].unique()

# delete capped values
trainset.drop(trainset[trainset["median_house_value"] >= 500001].index, inplace=True)
testset.drop(testset[testset["median_house_value"] >= 500001].index, inplace=True)

# %% [markdown]
# ## Dummy variables

# %%
from sklearn.preprocessing import OneHotEncoder

one_hot_encoder = OneHotEncoder(drop="first", sparse_output=False)

# categorical columns to transform
cat_cols = ["ocean_proximity"]

# fit an encoder and transform the **trainset**
cat_vals = trainset[cat_cols]

transformed = one_hot_encoder.fit_transform(cat_vals)

# the names of the new columns are the unique values of "ocean_proximity"
new_col_names = one_hot_encoder.get_feature_names_out(cat_cols)

# put the transformed data as columns in the trainset dataframe
for i, new_col_name in enumerate(new_col_names):
    trainset[new_col_name] = transformed[:,i]

# delete the categorical column
del trainset['ocean_proximity']

# transform the **testset** using the encoder fitted on trainset
cat_vals = testset[cat_cols]
transformed = one_hot_encoder.transform(cat_vals)

# put the transformed data as columns in the testset dataframe
for i, new_col_name in enumerate(new_col_names):
    testset[new_col_name] = transformed[:,i]

# delete the categorical column also in the test set
del testset['ocean_proximity']

# %% [markdown]
# ## Separate predictors and target

# %%
ytrain = trainset["median_house_value"].copy()
Xtrain = trainset.drop("median_house_value", axis=1)
ytest = testset["median_house_value"].copy()
Xtest = testset.drop("median_house_value", axis=1)

# %% [markdown]
# # Pipeline

# %%
from imblearn.pipeline import Pipeline
from sklearn.ensemble import IsolationForest
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import r_regression
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error


class LogTransformer:

    def __init__(self, cols, **kwargs):
        self.cols = cols

    def fit(self, X, y=None, **kwargs):
        return self

    def transform(self, X, y=None, **kwargs):
        for col in self.cols:
            X[:, col] = np.log(X[:, col] + 1)
        return X


class OutlierDetectionWrapper():

    def __init__(self, **kwargs):
        self.clf = IsolationForest(**kwargs)

    def fit_resample(self, X, y):
        yhat = self.clf.fit(X).predict(X)
        return X[yhat != -1], y[yhat != -1]

    def set_params(self, **kwargs):
        self.clf.set_params(**kwargs)


# indices of columns to be log-transformed
col_idx = [Xtrain.columns.get_loc(x) for x in 
           ["total_rooms", "total_bedrooms", "population", "households", "median_income"]]

pipe = Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    ('logtransformer', LogTransformer(col_idx)),
    ('iforest', OutlierDetectionWrapper(n_estimators=100, random_state=7, contamination=0.03)),
    ('fsel', SelectKBest(r_regression, k=10)),
    ('scaler', StandardScaler()),
    ('dt', DecisionTreeRegressor(random_state=7))
])

pipe.fit(Xtrain, ytrain)

yhat = pipe.predict(Xtest)
tree_mse = mean_squared_error(ytest, yhat)
tree_rmse = np.sqrt(tree_mse)
tree_rmse
# Out:
# 74388.82096572242

# %% [markdown]
# # Tuning hyperparameters

# %%
from skopt import BayesSearchCV

# %%
start = timer()

pipe = Pipeline([
    ('imputer', SimpleImputer()),
    ('logtransformer', LogTransformer(col_idx)),
    ('iforest', OutlierDetectionWrapper(random_state=7)),
    ('fsel', SelectKBest(r_regression)),
    ('scaler', StandardScaler()),
    ('dt', DecisionTreeRegressor(random_state=7))
])

hp_grid = {
    'imputer__strategy': ["mean", "median"],
    'iforest__contamination': [0.001, 0.1],
    'iforest__n_estimators': [1, 50],
    'fsel__k': [3, 13],
    'dt__max_depth': [2, 25],
    'dt__min_samples_leaf': [1, 50],
    'dt__min_samples_split': [2, 50],
    'dt__max_leaf_nodes': [5000, 16000]  
}

opt_grid_search = BayesSearchCV(
     pipe,
     hp_grid,
     n_iter=30,
     random_state=7,
     scoring='neg_root_mean_squared_error',
     return_train_score=True,
     cv=10
)

np.int = int
opt_grid_search.fit(Xtrain, ytrain)

print("Execution time HH:MM:SS:", timedelta(seconds=timer() - start))
# Out:
# Execution time HH:MM:SS: 0:02:45.890431

# %%
opt_grid_search.best_estimator_
# Out:
# Pipeline(steps=[('imputer', SimpleImputer()),
#                 ('logtransformer',
#                  <__main__.LogTransformer object at 0x00000240EC5690A0>),
#                 ('iforest',
#                  <__main__.OutlierDetectionWrapper object at 0x00000240EC5693A0>),
#                 ('fsel',
#                  SelectKBest(k=13,
#                              score_func=<function r_regression at 0x00000240E9F06A60>)),
#                 ('scaler', StandardScaler()),
#                 ('dt',
#                  DecisionTreeRegressor(max_depth=25, max_leaf_nodes=16000,
#                                        min_samples_leaf=15,
#                                        min_samples_split=50, random_state=7))])

# %%
-opt_grid_search.best_score_
# Out:
# 52642.96661171813

# %%
cv_results = pd.DataFrame(opt_grid_search.cv_results_)[['params', 'mean_train_score', 'mean_test_score']]
cv_results["mean_train_score"] = -cv_results["mean_train_score"]
cv_results["mean_test_score"] = -cv_results["mean_test_score"]
cv_results["diff, %"] = 100*(cv_results["mean_train_score"]-cv_results["mean_test_score"]
                                                     )/cv_results["mean_train_score"]

cv_results.sort_values('mean_test_score')
# Out:
#                                                                                                                                                                                                                                  params  \
# 28                {'dt__max_depth': 25, 'dt__max_leaf_nodes': 16000, 'dt__min_samples_leaf': 15, 'dt__min_samples_split': 50, 'fsel__k': 13, 'iforest__contamination': 0.001, 'iforest__n_estimators': 50, 'imputer__strategy': 'mean'}
# 29                {'dt__max_depth': 25, 'dt__max_leaf_nodes': 16000, 'dt__min_samples_leaf': 17, 'dt__min_samples_split': 50, 'fsel__k': 13, 'iforest__contamination': 0.001, 'iforest__n_estimators': 50, 'imputer__strategy': 'mean'}
# 25                {'dt__max_depth': 24, 'dt__max_leaf_nodes': 16000, 'dt__min_samples_leaf': 20, 'dt__min_samples_split': 50, 'fsel__k': 13, 'iforest__contamination': 0.001, 'iforest__n_estimators': 50, 'imputer__strategy': 'mean'}
# 27                {'dt__max_depth': 25, 'dt__max_leaf_nodes': 16000, 'dt__min_samples_leaf': 16, 'dt__min_samples_split': 50, 'fsel__k': 13, 'iforest__contamination': 0.001, 'iforest__n_estimators': 50, 'imputer__strategy': 'mean'}
# 26                {'dt__max_depth': 24, 'dt__max_leaf_nodes': 16000, 'dt__min_samples_leaf': 12, 'dt__min_samples_split': 50, 'fsel__k': 13, 'iforest__contamination': 0.001, 'iforest__n_estimators': 50, 'imputer__strategy': 'mean'}
# 24                {'dt__max_depth': 24, 'dt__max_leaf_nodes': 16000, 'dt__min_samples_leaf': 29, 'dt__min_samples_split': 50, 'fsel__k': 13, 'iforest__contamination': 0.001, 'iforest__n_estimators': 50, 'imputer__strategy': 'mean'}
# 21                {'dt__max_depth': 24, 'dt__max_leaf_nodes': 15932, 'dt__min_samples_leaf': 34, 'dt__min_samples_split': 50, 'fsel__k': 13, 'iforest__contamination': 0.001, 'iforest__n_estimators': 50, 'imputer__strategy': 'mean'}
# 22                 {'dt__max_depth': 24, 'dt__max_leaf_nodes': 7203, 'dt__min_samples_leaf': 32, 'dt__min_samples_split': 50, 'fsel__k': 13, 'iforest__contamination': 0.001, 'iforest__n_estimators': 50, 'imputer__strategy': 'mean'}
# 20                {'dt__max_depth': 24, 'dt__max_leaf_nodes': 13620, 'dt__min_samples_leaf': 33, 'dt__min_samples_split': 50, 'fsel__k': 13, 'iforest__contamination': 0.001, 'iforest__n_estimators': 50, 'imputer__strategy': 'mean'}
# 19                {'dt__max_depth': 25, 'dt__max_leaf_nodes': 16000, 'dt__min_samples_leaf': 36, 'dt__min_samples_split': 50, 'fsel__k': 13, 'iforest__contamination': 0.001, 'iforest__n_estimators': 50, 'imputer__strategy': 'mean'}
# 23  {'dt__max_depth': 24, 'dt__max_leaf_nodes': 5000, 'dt__min_samples_leaf': 35, 'dt__min_samples_split': 50, 'fsel__k': 13, 'iforest__contamination': 0.003370974049155599, 'iforest__n_estimators': 50, 'imputer__strategy': 'mean'}
# 13                    {'dt__max_depth': 25, 'dt__max_leaf_nodes': 5000, 'dt__min_samples_leaf': 38, 'dt__min_samples_split': 2, 'fsel__k': 13, 'iforest__contamination': 0.1, 'iforest__n_estimators': 50, 'imputer__strategy': 'mean'}
# 17    {'dt__max_depth': 25, 'dt__max_leaf_nodes': 8585, 'dt__min_samples_leaf': 36, 'dt__min_samples_split': 2, 'fsel__k': 13, 'iforest__contamination': 0.09269860070617089, 'iforest__n_estimators': 49, 'imputer__strategy': 'mean'}
# 16                    {'dt__max_depth': 23, 'dt__max_leaf_nodes': 5000, 'dt__min_samples_leaf': 41, 'dt__min_samples_split': 2, 'fsel__k': 13, 'iforest__contamination': 0.1, 'iforest__n_estimators': 50, 'imputer__strategy': 'mean'}
# 14                 {'dt__max_depth': 25, 'dt__max_leaf_nodes': 16000, 'dt__min_samples_leaf': 50, 'dt__min_samples_split': 2, 'fsel__k': 13, 'iforest__contamination': 0.001, 'iforest__n_estimators': 50, 'imputer__strategy': 'mean'}
# 18                     {'dt__max_depth': 25, 'dt__max_leaf_nodes': 5000, 'dt__min_samples_leaf': 43, 'dt__min_samples_split': 2, 'fsel__k': 13, 'iforest__contamination': 0.1, 'iforest__n_estimators': 5, 'imputer__strategy': 'mean'}
# 8   {'dt__max_depth': 22, 'dt__max_leaf_nodes': 11838, 'dt__min_samples_leaf': 35, 'dt__min_samples_split': 14, 'fsel__k': 12, 'iforest__contamination': 0.07179766430645908, 'iforest__n_estimators': 48, 'imputer__strategy': 'mean'}
# 10  {'dt__max_depth': 23, 'dt__max_leaf_nodes': 11444, 'dt__min_samples_leaf': 39, 'dt__min_samples_split': 16, 'fsel__k': 12, 'iforest__contamination': 0.07179840036154128, 'iforest__n_estimators': 48, 'imputer__strategy': 'mean'}
# 12  {'dt__max_depth': 23, 'dt__max_leaf_nodes': 13015, 'dt__min_samples_leaf': 37, 'dt__min_samples_split': 26, 'fsel__k': 12, 'iforest__contamination': 0.05431164803766281, 'iforest__n_estimators': 24, 'imputer__strategy': 'mean'}
# 3    {'dt__max_depth': 10, 'dt__max_leaf_nodes': 13402, 'dt__min_samples_leaf': 38, 'dt__min_samples_split': 25, 'fsel__k': 10, 'iforest__contamination': 0.08877128623311789, 'iforest__n_estimators': 7, 'imputer__strategy': 'mean'}
# 2    {'dt__max_depth': 10, 'dt__max_leaf_nodes': 10924, 'dt__min_samples_leaf': 48, 'dt__min_samples_split': 50, 'fsel__k': 9, 'iforest__contamination': 0.0528993431876014, 'iforest__n_estimators': 6, 'imputer__strategy': 'median'}
# 7   {'dt__max_depth': 21, 'dt__max_leaf_nodes': 14950, 'dt__min_samples_leaf': 27, 'dt__min_samples_split': 49, 'fsel__k': 9, 'iforest__contamination': 0.052938573401785344, 'iforest__n_estimators': 39, 'imputer__strategy': 'mean'}
# 9   {'dt__max_depth': 14, 'dt__max_leaf_nodes': 7134, 'dt__min_samples_leaf': 43, 'dt__min_samples_split': 34, 'fsel__k': 9, 'iforest__contamination': 0.08857480379964548, 'iforest__n_estimators': 37, 'imputer__strategy': 'median'}
# 0       {'dt__max_depth': 25, 'dt__max_leaf_nodes': 14445, 'dt__min_samples_leaf': 49, 'dt__min_samples_split': 7, 'fsel__k': 7, 'iforest__contamination': 0.043412138330431, 'iforest__n_estimators': 28, 'imputer__strategy': 'mean'}
# 1   {'dt__max_depth': 15, 'dt__max_leaf_nodes': 15867, 'dt__min_samples_leaf': 33, 'dt__min_samples_split': 28, 'fsel__k': 7, 'iforest__contamination': 0.039703085047976164, 'iforest__n_estimators': 36, 'imputer__strategy': 'mean'}
# 5   {'dt__max_depth': 25, 'dt__max_leaf_nodes': 14675, 'dt__min_samples_leaf': 41, 'dt__min_samples_split': 16, 'fsel__k': 7, 'iforest__contamination': 0.011054260659967001, 'iforest__n_estimators': 14, 'imputer__strategy': 'mean'}
# 15                  {'dt__max_depth': 2, 'dt__max_leaf_nodes': 16000, 'dt__min_samples_leaf': 43, 'dt__min_samples_split': 2, 'fsel__k': 13, 'iforest__contamination': 0.1, 'iforest__n_estimators': 50, 'imputer__strategy': 'median'}
# 4     {'dt__max_depth': 13, 'dt__max_leaf_nodes': 10236, 'dt__min_samples_leaf': 9, 'dt__min_samples_split': 41, 'fsel__k': 4, 'iforest__contamination': 0.04678644133359494, 'iforest__n_estimators': 14, 'imputer__strategy': 'mean'}
# 6     {'dt__max_depth': 23, 'dt__max_leaf_nodes': 9922, 'dt__min_samples_leaf': 5, 'dt__min_samples_split': 3, 'fsel__k': 8, 'iforest__contamination': 0.04457121361168331, 'iforest__n_estimators': 13, 'imputer__strategy': 'median'}
# 11     {'dt__max_depth': 2, 'dt__max_leaf_nodes': 16000, 'dt__min_samples_leaf': 1, 'dt__min_samples_split': 2, 'fsel__k': 12, 'iforest__contamination': 0.07150563371065301, 'iforest__n_estimators': 42, 'imputer__strategy': 'mean'}
#
#     mean_train_score  mean_test_score    diff, %
# 28      44395.887582     52642.966612 -18.576223
# 29      44626.515057     52658.269420 -17.997718
# 25      45018.573880     52682.373385 -17.023639
# 27      44534.866190     52718.491803 -18.375772
# 26      43998.771035     52825.284251 -20.060818
# 24      46796.849617     53062.958222 -13.390022
# 21      47722.558866     53277.000951 -11.639028
# 22      47381.173593     53279.589680 -12.448860
# 20      47570.075035     53340.033205 -12.129386
# 19      48036.574560     53343.106733 -11.046858
# 23      47947.974050     53503.423848 -11.586412
# 13      49753.846376     53683.885111  -7.898965
# 17      49411.046692     53795.467860  -8.873362
# 16      50173.305989     53828.112739  -7.284365
# 14      49987.804503     53900.771897  -7.827844
# 18      50393.489388     54578.193478  -8.304057
# 8       51052.762479     56465.293059 -10.601837
# 10      51686.353557     56484.329327  -9.282868
# 12      51709.226660     56719.015961  -9.688386
# 3       58651.312014     63494.200523  -8.257085
# 2       61484.499949     65958.626694  -7.276837
# 7       58740.910165     66393.725746 -13.028085
# 9       61129.058047     66591.074813  -8.935222
# 0       63087.467888     67483.914111  -6.968811
# 1       61720.703243     67718.626667  -9.717847
# 5       64140.462538     69019.452654  -7.606727
# 15      72417.428186     72684.927659  -0.369385
# 4       64422.802803     73950.739193 -14.789696
# 6       46892.929157     76545.325693 -63.234260
# 11      76545.056361     76778.950583  -0.305564

# %% [markdown]
# # Citing this notebook
#
# If you use this notebook in your work, please cite it as follows:
#
# Pekar, V. (2024). Big Data for Decision Making. Lecture examples and exercises. (Version 1.0.0). URL: https://github.com/vpekar/bd4dm
